# %%
import pandas as pd
scores = pd.read_csv(r'C:\Users\吴凌宇\Desktop\numpy，pandas小练习\data\score.csv',encoding='gbk')

# %%
scores
# Out:
#     姓名  语文  数学  英语   总分
# 0   陈纯  88  87  85  260
# 1  方小磊  93  88  90  271
# 2   王妤  82  99  96  277
# 3  彭子晖  97  94  84  275
# 4  丁海斌  97  94  76  267

# %%
scores['姓名']
# Out:
# 0     陈纯
# 1    方小磊
# 2     王妤
# 3    彭子晖
# 4    丁海斌
# Name: 姓名, dtype: object

# %%
scores.loc(0)

# %%
scores.loc[0:1,'语文':'英语']
# Out:
#    语文  数学  英语
# 0  88  87  85
# 1  93  88  90

# %%
scores.iloc[:,[1,2,3]]
# Out:
#    语文  数学  英语
# 0  88  87  85
# 1  93  88  90
# 2  82  99  96
# 3  97  94  84
# 4  97  94  76

# %%
scores.ix[:,'语文':'英语']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-17f3eb8d508e> in <module>
# ----> 1 scores.ix[:,'语文':'英语']
#
# D:\Anaconda3-2020.02\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
scores[(scores.index>=1)&(scores.index<=3)&(scores.数学>=90)]
# Out:
#     姓名  语文  数学  英语   总分
# 2   王妤  82  99  96  277
# 3  彭子晖  97  94  84  275

# %%
scores.loc[1:3][scores.数学>=90]
# Out:
# D:\Anaconda3-2020.02\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     姓名  语文  数学  英语   总分
# 2   王妤  82  99  96  277
# 3  彭子晖  97  94  84  275

# %%
scores[scores.姓名.str.contains('陈')]
# Out:
#    姓名  语文  数学  英语   总分
# 0  陈纯  88  87  85  260

# %%
scores[scores.姓名.str.contains('晖')]
# Out:
#     姓名  语文  数学  英语   总分
# 3  彭子晖  97  94  84  275

# %%
scores.mean()
# Out:
# 语文     91.4
# 数学     92.4
# 英语     86.2
# 总分    270.0
# dtype: float64

# %%
scores.数学.mean()
# Out:
# 92.4

# %%
scores.sort_values(by='总分')
# Out:
#     姓名  语文  数学  英语   总分
# 0   陈纯  88  87  85  260
# 4  丁海斌  97  94  76  267
# 1  方小磊  93  88  90  271
# 3  彭子晖  97  94  84  275
# 2   王妤  82  99  96  277

# %%
scores.sort_values(by='总分')[:3].姓名
# Out:
# 0     陈纯
# 4    丁海斌
# 1    方小磊
# Name: 姓名, dtype: object

# %%
help(scores.sort_values)
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False) method of pandas.core.frame.DataFrame instance
#     Sort by the values along either axis.
#
#     Parameters
#     ----------
#             by : str or list of str
#                 Name or list of names to sort by.
#
#                 - if `axis` is 0 or `'index'` then `by` may contain index
#                   levels and/or column labels.
#                 - if `axis` is 1 or `'columns'` then `by` may contain column
#                   levels and/or index labels.
#
#                 .. versionchanged:: 0.23.0
#
#                    Allow specifying index or column level names.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#          Axis to be sorted.
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
# ...

# %%
scores[scores.数学>=90].mean()
# Out:
# 语文     92.000000
# 数学     95.666667
# 英语     85.333333
# 总分    273.000000
# dtype: float64

# %%
len(scores[scores.总分>=270])
# Out:
# 3

# %%
scores['grade']=['A' if element>=270 else "B" for element in scores.总分]

# %%
scores
# Out:
#     姓名  语文  数学  英语   总分 grade
# 0   陈纯  88  87  85  260     B
# 1  方小磊  93  88  90  271     A
# 2   王妤  82  99  96  277     A
# 3  彭子晖  97  94  84  275     A
# 4  丁海斌  97  94  76  267     B

# %%
mark=['A' if element>=270 else "B" for element in scores.总分]

# %%
mark
# Out:
# ['B', 'A', 'A', 'A', 'B']

# %%
scores.groupby(mark)

# %%
scores.groupby(mark).groups
# Out:
# {'A': Int64Index([1, 2, 3], dtype='int64'),
#  'B': Int64Index([0, 4], dtype='int64')}

# %%
for k,v in scores.groupby(mark):
    print(k,v)
# Out:
# A     姓名  语文  数学  英语   总分 grade
# 1  方小磊  93  88  90  271     A
# 2   王妤  82  99  96  277     A
# 3  彭子晖  97  94  84  275     A
# B     姓名  语文  数学  英语   总分 grade
# 0   陈纯  88  87  85  260     B
# 4  丁海斌  97  94  76  267     B

# %%
scores.groupby(mark).count()
# Out:
#    姓名  语文  数学  英语  总分  grade
# A   3   3   3   3   3      3
# B   2   2   2   2   2      2

# %%
scores.groupby(mark).姓名.count()
# Out:
# A    3
# B    2
# Name: 姓名, dtype: int64

# %%
import tushare as ts

ts.get_hist_data('600848') #一次性获取全部日k线数据
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2020-04-24  19.59  19.68  19.23  19.20   28405.81         -0.33     -1.69
# 2020-04-23  19.60  19.80  19.56  19.47   30939.72          0.04      0.20
# 2020-04-22  19.62  19.65  19.52  19.35   31077.09         -0.16     -0.81
# 2020-04-21  19.79  20.15  19.68  19.63   60891.04          0.03      0.15
# 2020-04-20  19.54  19.80  19.65  19.02   42648.44          0.13      0.67
# ...           ...    ...    ...    ...        ...           ...       ...
# 2017-10-31  32.62  35.22  34.44  32.20  361660.88          2.38      7.42
# 2017-10-30  32.56  34.40  32.06  31.85  337772.31         -1.05     -3.17
# 2017-10-27  31.45  33.20  33.11  31.45  333824.31          0.70      2.16
# 2017-10-26  29.30  32.70  32.41  28.92  501915.41          2.68      9.01
# 2017-10-25  27.86  30.45  29.73  27.54  328947.31          1.68      5.99
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20
# ...

# %%
df=ts.get_hist_data('600848',start='2019-01-01',end='2019-12-31')

# %%
df
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# date
# 2019-12-31  24.89  25.23  24.55  24.43  86431.63          0.47      1.95
# 2019-12-30  23.72  24.16  24.08  23.72  52275.18          0.33      1.39
# 2019-12-27  23.97  24.09  23.75  23.75  36809.18         -0.23     -0.96
# 2019-12-26  23.93  24.14  23.98  23.77  34415.24          0.05      0.21
# 2019-12-25  24.30  24.30  23.93  23.86  44607.62         -0.34     -1.40
# ...           ...    ...    ...    ...       ...           ...       ...
# 2019-01-08  21.26  21.58  20.90  20.89  57656.85         -0.36     -1.69
# 2019-01-07  20.65  21.66  21.26  20.60  76365.69          0.73      3.56
# 2019-01-04  19.70  20.60  20.53  19.60  46048.34          0.51      2.55
# 2019-01-03  20.75  20.99  20.02  19.99  53287.00         -0.65     -3.15
# 2019-01-02  20.37  20.94  20.67  20.37  35378.94         -0.01     -0.05
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20
# date
# ...

# %%
mark=df.loc[:,['open']]

# %%
mark
# Out:
#              open
# date
# 2019-12-31  24.89
# 2019-12-30  23.72
# 2019-12-27  23.97
# 2019-12-26  23.93
# 2019-12-25  24.30
# ...           ...
# 2019-01-08  21.26
# 2019-01-07  20.65
# 2019-01-04  19.70
# 2019-01-03  20.75
# 2019-01-02  20.37
#
# [243 rows x 1 columns]

# %%
df.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# date
# 2019-12-31  24.89  25.23  24.55  24.43  86431.63          0.47      1.95
# 2019-12-30  23.72  24.16  24.08  23.72  52275.18          0.33      1.39
# 2019-12-27  23.97  24.09  23.75  23.75  36809.18         -0.23     -0.96
# 2019-12-26  23.93  24.14  23.98  23.77  34415.24          0.05      0.21
# 2019-12-25  24.30  24.30  23.93  23.86  44607.62         -0.34     -1.40
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20
# date
# 2019-12-31  24.058  24.317  24.320  50907.77  47555.56  54514.24
# 2019-12-30  24.002  24.385  24.284  39689.94  47281.90  51736.82
# 2019-12-27  24.014  24.474  24.282  37666.28  50346.89  52540.88
# 2019-12-26  24.226  24.519  24.257  37242.81  58063.98  53186.77
# 2019-12-25  24.372  24.534  24.241  40259.12  58974.46  53886.04

# %%
df.shape
# Out:
# (243, 13)

# %%
df.index
# Out:
# Index(['2019-12-31', '2019-12-30', '2019-12-27', '2019-12-26', '2019-12-25',
#        '2019-12-24', '2019-12-23', '2019-12-20', '2019-12-19', '2019-12-18',
#        ...
#        '2019-01-15', '2019-01-14', '2019-01-11', '2019-01-10', '2019-01-09',
#        '2019-01-08', '2019-01-07', '2019-01-04', '2019-01-03', '2019-01-02'],
#       dtype='object', name='date', length=243)

# %%
df.columns
# Out:
# Index(['open', 'high', 'close', 'low', 'volume', 'price_change', 'p_change',
#        'ma5', 'ma10', 'ma20', 'v_ma5', 'v_ma10', 'v_ma20'],
#       dtype='object')

# %%
df.loc[:,['open','close']]
# Out:
#              open  close
# date
# 2019-12-31  24.89  24.55
# 2019-12-30  23.72  24.08
# 2019-12-27  23.97  23.75
# 2019-12-26  23.93  23.98
# 2019-12-25  24.30  23.93
# ...           ...    ...
# 2019-01-08  21.26  20.90
# 2019-01-07  20.65  21.26
# 2019-01-04  19.70  20.53
# 2019-01-03  20.75  20.02
# 2019-01-02  20.37  20.67
#
# [243 rows x 2 columns]
